# %% [markdown]
# <a href="https://colab.research.google.com/github/pulivrthisaikiran13/pulivrthisaikiran13/blob/main/Compiler_Product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Improting Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Generating Dataset

# %%
data = {

    'Version No': pd.Series(['Version 1', 'Version 2', 'Version 3', 'Version 4', 'Version 5', 'Version 6', 'Version 7', 'Version 8', 'Version 9', 'Version 10', 'Version 11', 'Version 12', 'Version 13', 'Version 14', 'Version 15']),
    'Compilation Speed': pd.Series(['120 ms', '110 ms', '105 ms', '100 ms', '98 ms', '95 ms', '93 ms', '90 ms', '88 ms', '87 ms', '85 ms', '83 ms', '82 ms', '80 ms', '79 ms']),
    'Optimization Level': pd.Series([2, 2, 3, 2, 3, 3, 2, 3, 3, 2, 3, 3, 2, 3, 2]),
    'Memory Usage': pd.Series([50, 48, 45, 44, 42, 41, 40, 38, 37, 35, 34, 33, 32, 30, 29]),
    'Platform Support': pd.Series(['Win', 'Win', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac', 'Win, Mac']),
    'Error Detection': pd.Series(['High', 'High', 'Very High', 'High', 'Very High', 'Very High', 'High', 'Very High', 'Very High', 'High', 'Very High', 'Very High', 'High', 'Very High', 'High']),
    'Warning Levels': pd.Series([3, 3, 4, 3, 4, 4, 3, 4, 4, 3, 4, 4, 3, 4, 3]),
    'Debugging Tools': pd.Series(['Basic', 'Basic', 'Advanced', 'Basic', 'Advanced', 'Advanced', 'Basic', 'Advanced', 'Advanced', 'Basic', 'Advanced', 'Advanced', 'Basic', 'Advanced', 'Basic']),
    'Cross Compilation': pd.Series(['No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No']),
    'Multi Threading': pd.Series(['Limited', 'Limited', 'Full', 'Limited', 'Full', 'Full', 'Limited', 'Full', 'Full', 'Limited', 'Full', 'Full', 'Limited', 'Full', 'Limited']),
    'Library Support': pd.Series(['Standard', 'Standard', 'Extended', 'Standard', 'Extended', 'Extended', 'Standard', 'Extended', 'Extended', 'Standard', 'Extended', 'Extended', 'Standard', 'Extended', 'Standard']),
    'Version Years': pd.Series([1987, 1992, 2001, 2005, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]),
    'Static Analysis': pd.Series(['Basic', 'Basic', 'Advanced', 'Basic', 'Advanced', 'Advanced', 'Basic', 'Advanced', 'Advanced', 'Basic', 'Advanced', 'Advanced', 'Basic', 'Advanced' 'Basic']),
    'Code Generation': pd.Series(['Fast', 'Fast', 'Faster', 'Fast', 'Faster', 'Faster', 'Fast', 'Faster', 'Faster', 'Fast', 'Faster', 'Faster', 'Fast', 'Faster', 'Fast']),
    'Open MP Support': pd.Series(['No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No']),
    'Supported Languages': pd.Series(['C', 'C', 'C, C++', 'C', 'C, C++', 'C, C++', 'C', 'C, C++', 'C, C++', 'C', 'C, C++', 'C, C++', 'C', 'C, C++', 'C'])
}

# %% [markdown]
# # Coversion of Dataset into DataFrame

# %%
df=pd.DataFrame(data)
df
# Out:
#     Version No Compilation Speed  Optimization Level  Memory Usage  \
# 0    Version 1            120 ms                   2            50
# 1    Version 2            110 ms                   2            48
# 2    Version 3            105 ms                   3            45
# 3    Version 4            100 ms                   2            44
# 4    Version 5             98 ms                   3            42
# 5    Version 6             95 ms                   3            41
# 6    Version 7             93 ms                   2            40
# 7    Version 8             90 ms                   3            38
# 8    Version 9             88 ms                   3            37
# 9   Version 10             87 ms                   2            35
# 10  Version 11             85 ms                   3            34
# 11  Version 12             83 ms                   3            33
# 12  Version 13             82 ms                   2            32
# ...

# %% [markdown]
# # Index Changing

# %%
df.index = range(1001, 1001+ len(df))
df
# Out:
#       Version No Compilation Speed  Optimization Level  Memory Usage  \
# 1001   Version 1            120 ms                   2            50
# 1002   Version 2            110 ms                   2            48
# 1003   Version 3            105 ms                   3            45
# 1004   Version 4            100 ms                   2            44
# 1005   Version 5             98 ms                   3            42
# 1006   Version 6             95 ms                   3            41
# 1007   Version 7             93 ms                   2            40
# 1008   Version 8             90 ms                   3            38
# 1009   Version 9             88 ms                   3            37
# 1010  Version 10             87 ms                   2            35
# 1011  Version 11             85 ms                   3            34
# 1012  Version 12             83 ms                   3            33
# 1013  Version 13             82 ms                   2            32
# ...

# %% [markdown]
# # Before Applying CRUD Operations

# %% [markdown]
# # No.of Rows and Columns

# %%
print(df.shape)
# Out:
# (15, 16)

# %% [markdown]
# # Accessing Last Five Rows

# %%
df.tail()
# Out:
#       Version No Compilation Speed  Optimization Level  Memory Usage  \
# 1011  Version 11             85 ms                   3            34
# 1012  Version 12             83 ms                   3            33
# 1013  Version 13             82 ms                   2            32
# 1014  Version 14             80 ms                   3            30
# 1015  Version 15             79 ms                   2            29
#
#      Platform Support Error Detection  Warning Levels Debugging Tools  \
# 1011         Win, Mac       Very High               4        Advanced
# 1012         Win, Mac       Very High               4        Advanced
# 1013         Win, Mac            High               3           Basic
# 1014         Win, Mac       Very High               4        Advanced
# 1015         Win, Mac            High               3           Basic
#
#      Cross Compilation Multi Threading Library Support  Version Years  \
# ...

# %% [markdown]
# # Accessing First Five Rows

# %%
df.head()
# Out:
#      Version No Compilation Speed  Optimization Level  Memory Usage  \
# 1001  Version 1            120 ms                   2            50
# 1002  Version 2            110 ms                   2            48
# 1003  Version 3            105 ms                   3            45
# 1004  Version 4            100 ms                   2            44
# 1005  Version 5             98 ms                   3            42
#
#      Platform Support Error Detection  Warning Levels Debugging Tools  \
# 1001              Win            High               3           Basic
# 1002              Win            High               3           Basic
# 1003         Win, Mac       Very High               4        Advanced
# 1004         Win, Mac            High               3           Basic
# 1005         Win, Mac       Very High               4        Advanced
#
#      Cross Compilation Multi Threading Library Support  Version Years  \
# ...

# %% [markdown]
# # Display Total Columns in Dataset

# %%
df.columns
# Out:
# Index(['Version No', 'Compilation Speed', 'Optimization Level', 'Memory Usage',
#        'Platform Support', 'Error Detection', 'Warning Levels',
#        'Debugging Tools', 'Cross Compilation', 'Multi Threading',
#        'Library Support', 'Version Years', 'Static Analysis',
#        'Code Generation', 'Open MP Support', 'Supported Languages'],
#       dtype='object')

# %% [markdown]
# # Column Types

# %%
df.dtypes
# Out:
# Version No             object
# Compilation Speed      object
# Optimization Level      int64
# Memory Usage            int64
# Platform Support       object
# Error Detection        object
# Warning Levels          int64
# Debugging Tools        object
# Cross Compilation      object
# Multi Threading        object
# Library Support        object
# Version Years           int64
# Static Analysis        object
# Code Generation        object
# Open MP Support        object
# Supported Languages    object
# dtype: object

# %% [markdown]
# # DataFrame Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 1001 to 1015
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Version No           15 non-null     object
#  1   Compilation Speed    15 non-null     object
#  2   Optimization Level   15 non-null     int64
#  3   Memory Usage         15 non-null     int64
#  4   Platform Support     15 non-null     object
#  5   Error Detection      15 non-null     object
#  6   Warning Levels       15 non-null     int64
#  7   Debugging Tools      15 non-null     object
#  8   Cross Compilation    15 non-null     object
#  9   Multi Threading      15 non-null     object
#  10  Library Support      15 non-null     object
#  11  Version Years        15 non-null     int64
#  12  Static Analysis      14 non-null     object
#  13  Code Generation      15 non-null     object
#  14  Open MP Support      15 non-null     object
# ...

# %% [markdown]
# # Describe DataFrame

# %%
df.describe()
# Out:
#        Optimization Level  Memory Usage  Warning Levels  Version Years
# count           15.000000     15.000000       15.000000      15.000000
# mean             2.533333     38.533333        3.533333    2012.933333
# std              0.516398      6.468237        0.516398      11.435950
# min              2.000000     29.000000        3.000000    1987.000000
# 25%              2.000000     33.500000        3.000000    2009.500000
# 50%              3.000000     38.000000        4.000000    2017.000000
# 75%              3.000000     43.000000        4.000000    2020.500000
# max              3.000000     50.000000        4.000000    2024.000000

# %% [markdown]
# # **Applying CRUD Operations**

# %% [markdown]
# **C = Create Dataset**

# %% [markdown]
# **R = Read/Retrive data from Dataset**

# %% [markdown]
# **U = Update**

# %% [markdown]
# **D = Delete**

# %%
df
# Out:
#       Version No Compilation Speed  Optimization Level  Memory Usage  \
# 1001   Version 1            120 ms                   2            50
# 1002   Version 2            110 ms                   2            48
# 1003   Version 3            105 ms                   3            45
# 1004   Version 4            100 ms                   2            44
# 1005   Version 5             98 ms                   3            42
# 1006   Version 6             95 ms                   3            41
# 1007   Version 7             93 ms                   2            40
# 1008   Version 8             90 ms                   3            38
# 1009   Version 9             88 ms                   3            37
# 1010  Version 10             87 ms                   2            35
# 1011  Version 11             85 ms                   3            34
# 1012  Version 12             83 ms                   3            33
# 1013  Version 13             82 ms                   2            32
# ...

# %% [markdown]
# # Create - Row Creating and Inserting

# %%
r = {
    'Version No': 'Version 16',
    'Compilation Speed': '75 ms',
    'Optimization Level': 3,
    'Memory usage': 27,
    'Platform Support': 'Win, Mac',
    'Error Detection': 'High',
    'Warning Levels': 3,
    'Debugging Tools': 'Basic',
    'Cross Compilation': 'Yes',
    'Multi Threading': 'Full',
    'Library Support': 'Standard',
    'Version Years': 2024,
    'Static Analysis': 'Basic',
    'Code Generation': 'Faster',
    'Supported Languages': 'C, C++'
    }
df_new= pd.concat([df, pd.DataFrame([r])], ignore_index=True)
df_new
# Out:
#     Version No Compilation Speed  Optimization Level  Memory Usage  \
# 0    Version 1            120 ms                   2          50.0
# 1    Version 2            110 ms                   2          48.0
# 2    Version 3            105 ms                   3          45.0
# 3    Version 4            100 ms                   2          44.0
# 4    Version 5             98 ms                   3          42.0
# 5    Version 6             95 ms                   3          41.0
# 6    Version 7             93 ms                   2          40.0
# 7    Version 8             90 ms                   3          38.0
# 8    Version 9             88 ms                   3          37.0
# 9   Version 10             87 ms                   2          35.0
# 10  Version 11             85 ms                   3          34.0
# 11  Version 12             83 ms                   3          33.0
# 12  Version 13             82 ms                   2          32.0
# ...

# %%
df.index = range(0, 0 + len(df))
df
# Out:
#     Version No Compilation Speed  Optimization Level  Memory Usage  \
# 0    Version 1            120 ms                   2            50
# 1    Version 2            110 ms                   2            48
# 2    Version 3            105 ms                   3            45
# 3    Version 4            100 ms                   2            44
# 4    Version 5             98 ms                   3            42
# 5    Version 6             95 ms                   3            41
# 6    Version 7             93 ms                   2            40
# 7    Version 8             90 ms                   3            38
# 8    Version 9             88 ms                   3            37
# 9   Version 10             87 ms                   2            35
# 10  Version 11             85 ms                   3            34
# 11  Version 12             83 ms                   3            33
# 12  Version 13             82 ms                   2            32
# ...

# %% [markdown]
# # Retrieving Inserted Row

# %%
df.tail(1)
# Out:
#     Version No Compilation Speed  Optimization Level  Memory Usage  \
# 14  Version 15             79 ms                   2            29
#
#    Platform Support Error Detection  Warning Levels Debugging Tools  \
# 14         Win, Mac            High               3           Basic
#
#    Cross Compilation Multi Threading Library Support  Version Years  \
# 14                No         Limited        Standard           2024
#
#    Static Analysis Code Generation Open MP Support Supported Languages
# 14             NaN            Fast              No                   C

# %% [markdown]
# # Creating Column and Insertion

# %%
df['Supported Softwares']=df['Supported Languages']+df['Code Generation']
df
# Out:
#     Version No Compilation Speed  Optimization Level  Memory Usage  \
# 0    Version 1            120 ms                   2            50
# 1    Version 2            110 ms                   2            48
# 2    Version 3            105 ms                   3            45
# 3    Version 4            100 ms                   2            44
# 4    Version 5             98 ms                   3            42
# 5    Version 6             95 ms                   3            41
# 6    Version 7             93 ms                   2            40
# 7    Version 8             90 ms                   3            38
# 8    Version 9             88 ms                   3            37
# 9   Version 10             87 ms                   2            35
# 10  Version 11             85 ms                   3            34
# 11  Version 12             83 ms                   3            33
# 12  Version 13             82 ms                   2            32
# ...

# %% [markdown]
# # Read/Retrieving Column

# %%
df['Compilation Speed']
# Out:
# 0     120 ms
# 1     110 ms
# 2     105 ms
# 3     100 ms
# 4      98 ms
# 5      95 ms
# 6      93 ms
# 7      90 ms
# 8      88 ms
# 9      87 ms
# 10     85 ms
# 11     83 ms
# 12     82 ms
# 13     80 ms
# 14     79 ms
# Name: Compilation Speed, dtype: object

# %% [markdown]
# # **Read/Retieve Data from DataFrame**

# %% [markdown]
# # Column Selection

# %%
df['Compilation Speed']
# Out:
# 0     120 ms
# 1     110 ms
# 2     105 ms
# 3     100 ms
# 4      98 ms
# 5      95 ms
# 6      93 ms
# 7      90 ms
# 8      88 ms
# 9      87 ms
# 10     85 ms
# 11     83 ms
# 12     82 ms
# 13     80 ms
# 14     79 ms
# Name: Compilation Speed, dtype: object

# %%
x=df['Optimization Level'][14]
print(x)
print()
y=df['Memory Usage'][14]
print(y)
print()
print(x*y)
# Out:
# 2
#
# 29
#
# 58

# %% [markdown]
# # Row Selection

# %%
df.loc[14]
# Out:
# Version No             Version 15
# Compilation Speed           79 ms
# Optimization Level              2
# Memory Usage                   29
# Platform Support         Win, Mac
# Error Detection              High
# Warning Levels                  3
# Debugging Tools             Basic
# Cross Compilation              No
# Multi Threading           Limited
# Library Support          Standard
# Version Years                2024
# Static Analysis               NaN
# Code Generation              Fast
# Open MP Support                No
# Supported Languages             C
# Supported Softwares         CFast
# Name: 14, dtype: object

# %% [markdown]
# # Specific Element in Column

# %%
df.loc[14],[14]
# Out:
# (Version No             Version 15
#  Compilation Speed           79 ms
#  Optimization Level              2
#  Memory Usage                   29
#  Platform Support         Win, Mac
#  Error Detection              High
#  Warning Levels                  3
#  Debugging Tools             Basic
#  Cross Compilation              No
#  Multi Threading           Limited
#  Library Support          Standard
#  Version Years                2024
#  Static Analysis               NaN
#  Code Generation              Fast
#  Open MP Support                No
#  Supported Languages             C
#  Name: 14, dtype: object,
#  [14])

# %% [markdown]
# # **Update the DataFrame**

# %% [markdown]
# # Update Columns

# %%
d={
    'Version No': 'Version_No',
    'Compilation Speed': 'Compilation_Speed',
    'Optimization Level': 'Optimization_Level',
    'Memory Usage': 'Memory_Usage',
    'Platform Support': 'Paltform_Support',
    'Error Detection': 'Error_Detection',
    'Warning Levels': 'Warning_Levels',
    'Debugging Tools': 'Debugging_Tools',
    'Cross Compilation': 'Cross_Compilation',
    'Multi Threading': 'Multi_Threading',
    'Library Support': 'Library_Support',
    'Version Years': 'Version_Years',
    'Static Analysis': 'Static_Analysis',
    'Code Generation': 'Code_Generation',
    'Open MP Support': 'Open MP_Support',
    'Supported Languages': 'Supported_Languages',
    'Supported Softwares': 'Supported_Softwares'
}

# %% [markdown]
# # After Updating Columns

# %%
df.columns
# Out:
# Index(['Version No', 'Compilation Speed', 'Optimization Level', 'Memory Usage',
#        'Platform Support', 'Error Detection', 'Warning Levels',
#        'Debugging Tools', 'Cross Compilation', 'Multi Threading',
#        'Library Support', 'Version Years', 'Static Analysis',
#        'Code Generation', 'Open MP Support', 'Supported Languages'],
#       dtype='object')

# %%
df
# Out:
#     Version No Compilation Speed  Optimization Level  Memory Usage  \
# 0    Version 1            120 ms                   2            50
# 1    Version 2            110 ms                   2            48
# 2    Version 3            105 ms                   3            45
# 3    Version 4            100 ms                   2            44
# 4    Version 5             98 ms                   3            42
# 5    Version 6             95 ms                   3            41
# 6    Version 7             93 ms                   2            40
# 7    Version 8             90 ms                   3            38
# 8    Version 9             88 ms                   3            37
# 9   Version 10             87 ms                   2            35
# 10  Version 11             85 ms                   3            34
# 11  Version 12             83 ms                   3            33
# 12  Version 13             82 ms                   2            32
# ...

# %% [markdown]
# # **Upadate in Columns**

# %% [markdown]
# # Before

# %%
df['Optimization Level'][11]
df['Optimization Level']
# Out:
# 0     2
# 1     2
# 2     3
# 3     2
# 4     3
# 5     3
# 6     2
# 7     3
# 8     3
# 9     2
# 10    3
# 11    3
# 12    2
# 13    3
# 14    2
# Name: Optimization Level, dtype: int64

# %% [markdown]
# # After

# %%
df['Optimization Level'][13]
df['Optimization Level']
# Out:
# 0     2
# 1     2
# 2     3
# 3     2
# 4     3
# 5     3
# 6     2
# 7     3
# 8     3
# 9     2
# 10    3
# 11    3
# 12    2
# 13    3
# 14    2
# Name: Optimization Level, dtype: int64

# %% [markdown]
# # Update Values in Rows

# %%
print(df.loc[12]['Optimization Level'])
print()
df.loc[12,'Optimization Level']=2
print(df.loc[12]['Optimization Level'])
# Out:
# 2
#
# 2

# %% [markdown]
# # **Deleting Data from DataFrame**

# %% [markdown]
# # Column Deletion

# %%
print(df.columns)
try:
  df.pop('Special Requests')
  print(d)
except KeyError:
  print("Column 'Special Requests' not found in DataFrame")
# Out:
# Index(['Version No', 'Compilation Speed', 'Optimization Level', 'Memory Usage',
#        'Platform Support', 'Error Detection', 'Warning Levels',
#        'Debugging Tools', 'Cross Compilation', 'Multi Threading',
#        'Library Support', 'Version Years', 'Static Analysis',
#        'Code Generation', 'Open MP Support', 'Supported Languages',
#        'Supported Softwares'],
#       dtype='object')
# Column 'Special Requests' not found in DataFrame

# %%
y=df_new.drop(['Memory Usage'])
y
# Out:
#     Version No Compilation Speed  Optimization Level  Memory Usage  \
# 0    Version 1            120 ms                   2          50.0
# 1    Version 2            110 ms                   2          48.0
# 2    Version 3            105 ms                   3          45.0
# 3    Version 4            100 ms                   2          44.0
# 4    Version 5             98 ms                   3          42.0
# 5    Version 6             95 ms                   3          41.0
# 6    Version 7             93 ms                   2          40.0
# 7    Version 8             90 ms                   3          38.0
# 8    Version 9             88 ms                   3          37.0
# 9   Version 10             87 ms                   2          35.0
# 10  Version 11             85 ms                   3          34.0
# 11  Version 12             83 ms                   3          33.0
# 12  Version 13             82 ms                   2          32.0
# ...

# %% [markdown]
# # **Final DataFrame**

# %%
df
# Out:
#     Version No Compilation Speed  Optimization Level  Memory Usage  \
# 0    Version 1            120 ms                   2            50
# 1    Version 2            110 ms                   2            48
# 2    Version 3            105 ms                   3            45
# 3    Version 4            100 ms                   2            44
# 4    Version 5             98 ms                   3            42
# 5    Version 6             95 ms                   3            41
# 6    Version 7             93 ms                   2            40
# 7    Version 8             90 ms                   3            38
# 8    Version 9             88 ms                   3            37
# 9   Version 10             87 ms                   2            35
# 10  Version 11             85 ms                   3            34
# 11  Version 12             83 ms                   3            33
# 12  Version 13             82 ms                   2            32
# ...

# %% [markdown]
# # **Correlation**

# %% [markdown]
# # Correlation Between Optimization Level and Memory Usage

# %%
cr1=df['Optimization Level'].corr(df['Memory Usage'])
print(cr1)

if cr1 > 0.5:
  pirnt("High Positive Relation")
elif 0 < cr1 <= 0.5:
  print("Low Positive Relation")
elif cr1 == 0:
  print("No Relation")
elif -0.5 < cr1 < 0:
  print("Low Negative Relation")
else:
  print("High Negative Relation")
# Out:
# -0.17677956959760543
# Low Negative Relation

# %% [markdown]
# # Correlation Between Optimization Level and Warnig Levels

# %%
cr2=df['Optimization Level'].corr(df['Warning Levels'])
print(cr2)

if cr2 > 0.5:
  print("High Positive Relation")
elif 0 < cr2 <= 0.5:
  print("Low Positive Relation")
elif cr2 == 0:
  print("No Relation")
elif -0.5 < cr2 < 0:
  print("Low Negative Relation")
else:
  print("High Negative Relation")
# Out:
# 1.0
# High Positive Relation

# %% [markdown]
# # Correlation between Memory Usage and Warning Levels

# %%
cr3=df['Memory Usage'].corr(df['Warning Levels'])
print(cr3)

if cr3 > 0.5:
  print("High Positive Relation")
elif 0 < cr3 <= 0.5:
  print("Low Positive Relation")
elif cr3 == 0:
  print("No Relation")
elif -0.5 < cr3 < 0:
  print("Low Negative Relation")
else:
  print("High Negative Relation")
# Out:
# -0.17677956959760546
# Low Negative Relation

# %% [markdown]
# # **Covarients**

# %% [markdown]
# # Covarience between Optimization Level and Memory Usage

# %%
cv1=df['Optimization Level'].cov(df['Memory Usage'])
print(cv1)

if cv1 > 0:
  print("Positive Covarience")
elif cv1 < 0:
  print("Negative Covarience")
else:
  print("No Covarience")
# Out:
# -0.590476190476191
# Negative Covarience

# %% [markdown]
# # Covarience between Optimization Level and Warning Levels

# %%
cv2=df['Optimization Level'].cov(df['Warning Levels'])
print(cv2)

if cv2 > 0:
  print("Positive Covarience")
elif cv2 < 0:
  print("Negative Covarience")
else:
  print("No Covarience")
# Out:
# 0.2666666666666668
# Positive Covarience

# %% [markdown]
# # **Finding Rank of the DataFrame**

# %%
df.rank()
# Out:
#     Version No  Compilation Speed  Optimization Level  Memory Usage  \
# 0          1.0                4.0                 4.0          15.0
# 1          8.0                3.0                 4.0          14.0
# 2          9.0                2.0                11.5          13.0
# 3         10.0                1.0                 4.0          12.0
# 4         11.0               15.0                11.5          11.0
# 5         12.0               14.0                11.5          10.0
# 6         13.0               13.0                 4.0           9.0
# 7         14.0               12.0                11.5           8.0
# 8         15.0               11.0                11.5           7.0
# 9          2.0               10.0                 4.0           6.0
# 10         3.0                9.0                11.5           5.0
# 11         4.0                8.0                11.5           4.0
# 12         5.0                7.0                 4.0           3.0
# ...

# %% [markdown]
# # **Filter In DataFrame**

# %%
df.filter(['Memory Usage','Version Years','Warning Levels'])
# Out:
#     Memory Usage  Version Years  Warning Levels
# 0             50           1987               3
# 1             48           1992               3
# 2             45           2001               4
# 3             44           2005               3
# 4             42           2014               4
# 5             41           2015               4
# 6             40           2016               3
# 7             38           2017               4
# 8             37           2018               4
# 9             35           2019               3
# 10            34           2020               4
# 11            33           2021               4
# 12            32           2022               3
# 13            30           2023               4
# 14            29           2024               3

# %% [markdown]
# # **GroupBY**

# %%
y=df.groupby(['Memory Usage','Warning Levels'])
print(y)

# %% [markdown]
# # **Aggregation**

# %%
df_numeric = df.apply(pd.to_numeric, errors='coerce')
df_numeric.aggregate(['sum'])
# Out:
#      Version No  Compilation Speed  Optimization Level  Memory Usage  \
# sum         0.0                0.0                  38           578
#
#      Platform Support  Error Detection  Warning Levels  Debugging Tools  \
# sum               0.0              0.0              53              0.0
#
#      Cross Compilation  Multi Threading  Library Support  Version Years  \
# sum                0.0              0.0              0.0          30194
#
#      Static Analysis  Code Generation  Open MP Support  Supported Languages  \
# sum              0.0              0.0              0.0                  0.0
#
#      Supported Softwares
# sum                  0.0

# %%
df_numeric = df.apply(pd.to_numeric, errors='coerce')
df_numeric.aggregate(['min'])
# Out:
#      Version No  Compilation Speed  Optimization Level  Memory Usage  \
# min         NaN                NaN                   2            29
#
#      Platform Support  Error Detection  Warning Levels  Debugging Tools  \
# min               NaN              NaN               3              NaN
#
#      Cross Compilation  Multi Threading  Library Support  Version Years  \
# min                NaN              NaN              NaN           1987
#
#      Static Analysis  Code Generation  Open MP Support  Supported Languages  \
# min              NaN              NaN              NaN                  NaN
#
#      Supported Softwares
# min                  NaN

# %%
df_numeric = df.apply(pd.to_numeric, errors='coerce')
df_numeric.aggregate(['max'])
# Out:
#      Version No  Compilation Speed  Optimization Level  Memory Usage  \
# max         NaN                NaN                   3            50
#
#      Platform Support  Error Detection  Warning Levels  Debugging Tools  \
# max               NaN              NaN               4              NaN
#
#      Cross Compilation  Multi Threading  Library Support  Version Years  \
# max                NaN              NaN              NaN           2024
#
#      Static Analysis  Code Generation  Open MP Support  Supported Languages  \
# max              NaN              NaN              NaN                  NaN
#
#      Supported Softwares
# max                  NaN

# %%
df_numeric = df.apply(pd.to_numeric, errors='coerce')
df_numeric.aggregate(['count'])
# Out:
#        Version No  Compilation Speed  Optimization Level  Memory Usage  \
# count           0                  0                  15            15
#
#        Platform Support  Error Detection  Warning Levels  Debugging Tools  \
# count                 0                0              15                0
#
#        Cross Compilation  Multi Threading  Library Support  Version Years  \
# count                  0                0                0             15
#
#        Static Analysis  Code Generation  Open MP Support  Supported Languages  \
# count                0                0                0                    0
#
#        Supported Softwares
# count                    0

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ## Univarient

# %%
df=pd.DataFrame(data)
plt.title("Compiler Graph")
plt.plot(df['Compilation Speed'])
plt.xlabel("Compilation Speed")
plt.ylabel("Optimization Level")
plt.grid()
plt.show()

# %% [markdown]
# # Bivarient

# %%
plt.plot(df['Compilation Speed'],df['Warning Levels'])
plt.title("Compiler Graph")
plt.xticks(rotation="vertical")
plt.xlabel("Compilation Speed")
plt.ylabel("Warning Levels")
plt.grid()
plt.show()

# %% [markdown]
# # Multivarient

# %%
plt.plot(df['Compilation Speed'],df['Warning Levels']),
plt.plot(df['Compilation Speed'],df['Optimization Level'])
plt.title("Compiler Graph")
plt.xticks(rotation="vertical")
plt.xlabel("Optimization Level")
plt.ylabel("Warning Levels")
plt.grid()
plt.show()

# %% [markdown]
# # Dashed Line

# %%
plt.plot(df['Compilation Speed'],df['Warning Levels'],linestyle="dashdot")
plt.xticks(rotation="vertical")
plt.title("Compiler Graph")
plt.xlabel("Compilation Speed")
plt.ylabel("Warning Levels")
plt.grid()

# %% [markdown]
# # Dotted Line

# %%
plt.plot(df['Compilation Speed'],df['Warning Levels'],linestyle="dotted")
plt.plot(df['Compilation Speed'],df['Optimization Level'],linestyle="dashdot")
plt.xticks(rotation="vertical")
plt.xlabel("Optimization Level")
plt.ylabel("Warning Levels")
plt.title("Compiler Graph")
plt.show()

# %% [markdown]
# # Line Width

# %%
df = pd.DataFrame(df)

plt.plot(df['Compilation Speed'],df['Warning Levels'],linestyle="solid",linewidth=3)
plt.plot(df['Compilation Speed'],df['Optimization Level'],linestyle="dashdot",linewidth=5)
plt.xticks(rotation="vertical")
plt.title("Compiler Graph")
plt.xlabel("Optimization Level")
plt.ylabel("Warning Levels")
plt.grid()
plt.show()

# %% [markdown]
# # Mark the Points

# %%
plt.plot(df['Compilation Speed'],df['Memory Usage'],linestyle="solid",marker="*")
plt.plot(df['Compilation Speed'],df['Optimization Level'],linestyle="solid",marker="o")
plt.xticks(rotation="vertical")
plt.title("Compiler Graph")
plt.xlabel("Optimization Level")
plt.ylabel("Memory Usage")
plt.grid()

# %% [markdown]
# # Legend

# %%
plt.plot(df['Compilation Speed'],df['Warning Levels'],linestyle="solid",marker="*",label="Warning Levels")
plt.plot(df['Compilation Speed'],df['Memory Usage'],linestyle="solid",marker="o",label="Optimization Level")
plt.xticks(rotation="vertical")
plt.title("Compiler Graph")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Scatter

# %%
plt.scatter(df['Compilation Speed'],df['Warning Levels'])
plt.xticks(rotation="vertical")
plt.title("Compiler Graph")
plt.xlabel("Compilation Speed")
plt.ylabel("Warning Levels")
plt.grid()
plt.show()

# %% [markdown]
# # Bar Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
df={'Warning_Levels': pd.Series([10, 20, 30, 40, 50, 60, 70, 80]),
    'Optimization_Level': pd.Series([10, 20, 30, 40, 50, 60, 70, 80])}
d=pd.DataFrame(df)
plt.bar(df['Warning_Levels'],df['Optimization_Level'],color="red")
plt.title("Compiler Graph")
plt.xlabel("Warning Levels")
plt.ylabel("Optimization Level")
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df={'Warning Levels': pd.Series([10, 20, 30, 40, 50, 60, 70, 80]),
    'Optimization Level': pd.Series([10, 20, 30, 40, 50, 60, 70, 80])}
d=pd.DataFrame(df)
plt.barh(df['Warning Levels'],df['Optimization Level'],color="blue")
plt.title("Compiler Graph")
plt.xlabel("Warning Levels")
plt.ylabel("Optimization Level")
plt.grid()
plt.show()

# %% [markdown]
# # Pie Charts

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Warning Levels' and 'Optimization Level' represent portions of a whole:
plt.pie(df['Warning Levels'], labels=df['Optimization Level'], autopct='%0.1f%%')
plt.title("Distribution of Warning Levels and Optimization")
plt.show()

# %% [markdown]
# **Exploding Pie Chart**

# %%
plt.pie(df['Warning Levels'], labels=df['Optimization Level'],
        autopct='%0.1f%%',explode=(0,0.5,0,0,0.4,0,0.3,0,0,0.5,0,0.4,0,0.7,0))
plt.title("Compiler Chart")
plt.show()

# %% [markdown]
# **Shadow**

# %%
plt.pie(df['Warning Levels'], labels=df['Optimization Level'],shadow=True,
        autopct='%0.1f%%',explode=(0,0.5,0,0,0.4,0,0.3,0,0,0.5,0,0.4,0,0.7,0))
plt.show()
